# %%
import numpy as np 
import tensorflow as tf
import pandas as pd
from tqdm import tqdm
import os
from cv2 import imread, createCLAHE 
import cv2
from glob import glob
import matplotlib.pyplot as plt
from IPython.display import clear_output
import random

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !kaggle datasets download -d nikhilpandey360/chest-xray-masks-and-labels
# Out:
# Downloading chest-xray-masks-and-labels.zip to /content
# 100% 9.57G/9.58G [03:21<00:00, 49.9MB/s]
# 100% 9.58G/9.58G [03:21<00:00, 51.0MB/s]

# %%
# !unzip chest-xray-masks-and-labels.zip
clear_output()

# %%
os.listdir('Lung Segmentation')
# Out:
# ['NLM-MontgomeryCXRSet-ReadMe.pdf',
#  '.ipynb_checkpoints',
#  'CXR_png',
#  'NLM-ChinaCXRSet-ReadMe.docx',
#  'masks',
#  'test',
#  'ClinicalReadings']

# %%
image_path = os.path.join("Lung Segmentation/CXR_png")
mask_path = os.path.join("Lung Segmentation/","masks/")

# %%
# we have 704 masks but 800 images. Hence we are going to
# make a 1-1 correspondance from mask to images, not the usual other way.
images = os.listdir(image_path)
mask = os.listdir(mask_path)
mask = [fName.split(".png")[0] for fName in mask]
image_file_name = [fName.split("_mask")[0] for fName in mask]

# %%
check = [i for i in mask if "mask" in i]
print("Total mask that has modified name:",len(check))
# Out:
# Total mask that has modified name: 566

# %%
testing_files = set(os.listdir(image_path)) & set(os.listdir(mask_path))
training_files = check

def getData(X_shape, flag = "test"):
    im_array = []
    mask_array = []
    
    if flag == "test":
        for i in tqdm(testing_files): 
            im = cv2.resize(cv2.imread(os.path.join(image_path,i)),(X_shape,X_shape))[:,:,0]
            mask = cv2.resize(cv2.imread(os.path.join(mask_path,i)),(X_shape,X_shape))[:,:,0]
            
            im_array.append(im)
            mask_array.append(mask)
        
        return im_array,mask_array
    
    if flag == "train":
        for i in tqdm(training_files): 
            im = cv2.resize(cv2.imread(os.path.join(image_path,i.split("_mask")[0]+".png")),(X_shape,X_shape))[:,:,0]
            mask = cv2.resize(cv2.imread(os.path.join(mask_path,i+".png")),(X_shape,X_shape))[:,:,0]

            im_array.append(im)
            mask_array.append(mask)

        return im_array,mask_array

# %%
#perform sanity check

def plotMask(X,y):
    sample = []
    offset = random.randint(0,100)
    
    for i in range(6):
        left = X[i+offset]
        right = y[i+offset]
        combined = np.hstack((left,right))
        sample.append(combined)
        
        
    for i in range(0,6,3):

        plt.figure(figsize=(25,10))
        
        plt.subplot(2,3,1+i)
        plt.imshow(sample[i])
        
        plt.subplot(2,3,2+i)
        plt.imshow(sample[i+1])
        
        
        plt.subplot(2,3,3+i)
        plt.imshow(sample[i+2])
        
        plt.show()

# %%
# Load training and testing data
dim = 256*2
X_train,y_train = getData(dim,flag="train")
X_test, y_test = getData(dim)
# Out:
# 100%|██████████| 566/566 [01:51<00:00,  5.07it/s]
# 100%|██████████| 138/138 [00:56<00:00,  2.44it/s]

# %%
print("training set")
plotMask(X_train,y_train)
print("testing set")
plotMask(X_test,y_test)
# Out:
# training set
# testing set

# %%
X_train = np.array(X_train).reshape(len(X_train),dim,dim,1)
y_train = np.array(y_train).reshape(len(y_train),dim,dim,1)
X_test = np.array(X_test).reshape(len(X_test),dim,dim,1)
y_test = np.array(y_test).reshape(len(y_test),dim,dim,1)
assert X_train.shape == y_train.shape
assert X_test.shape == y_test.shape
images = np.concatenate((X_train,X_test),axis=0)
mask  = np.concatenate((y_train,y_test),axis=0)

# %%
from keras.models import *
from keras.layers import *
from keras.optimizers import *
from keras import backend as keras
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, LearningRateScheduler


def dice_coef(y_true, y_pred):
    y_true_f = keras.flatten(y_true)
    y_pred_f = keras.flatten(y_pred)
    intersection = keras.sum(y_true_f * y_pred_f)
    return (2. * intersection + 1) / (keras.sum(y_true_f) + keras.sum(y_pred_f) + 1)

def dice_coef_loss(y_true, y_pred):
    return -dice_coef(y_true, y_pred)

def unet(input_size=(256,256,1)):
    inputs = Input(input_size)
    
    conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(inputs)
    conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

    conv2 = Conv2D(64, (3, 3), activation='relu', padding='same')(pool1)
    conv2 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)

    conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(pool2)
    conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)

    conv4 = Conv2D(256, (3, 3), activation='relu', padding='same')(pool3)
    conv4 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)

    conv5 = Conv2D(512, (3, 3), activation='relu', padding='same')(pool4)
    conv5 = Conv2D(512, (3, 3), activation='relu', padding='same')(conv5)

    up6 = concatenate([Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(conv5), conv4], axis=3)
    conv6 = Conv2D(256, (3, 3), activation='relu', padding='same')(up6)
    conv6 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv6)

    up7 = concatenate([Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(conv6), conv3], axis=3)
    conv7 = Conv2D(128, (3, 3), activation='relu', padding='same')(up7)
    conv7 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv7)

    up8 = concatenate([Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(conv7), conv2], axis=3)
    conv8 = Conv2D(64, (3, 3), activation='relu', padding='same')(up8)
    conv8 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv8)

    up9 = concatenate([Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(conv8), conv1], axis=3)
    conv9 = Conv2D(32, (3, 3), activation='relu', padding='same')(up9)
    conv9 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv9)

    conv10 = Conv2D(1, (1, 1), activation='sigmoid')(conv9)

    return Model(inputs=[inputs], outputs=[conv10])

# %%
from IPython.display import clear_output
# detect and init the TPU
tpu = tf.distribute.cluster_resolver.TPUClusterResolver()
tf.config.experimental_connect_to_cluster(tpu)
tf.tpu.experimental.initialize_tpu_system(tpu)
strategy = tf.distribute.experimental.TPUStrategy(tpu)
clear_output()

# %%
with strategy.scope():
  model = unet(input_size=(512,512,1))
  model.compile(optimizer=tf.keras.optimizers.Adam(lr=1e-5), loss=dice_coef_loss,
                    metrics=[dice_coef, 'binary_accuracy'])
  model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 512, 512, 1) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 512, 512, 32) 320         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 512, 512, 32) 9248        conv2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 256, 256, 32) 0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 256, 256, 64) 18496       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 256, 256, 64) 36928       conv2d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 128, 128, 64) 0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 128, 128, 128 73856       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 128, 128, 128 147584      conv2d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 64, 64, 128)  0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 64, 64, 256)  295168      max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 64, 64, 256)  590080      conv2d_6[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 32, 32, 256)  0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 32, 32, 512)  1180160     max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 32, 32, 512)  2359808     conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 64, 64, 256)  524544      conv2d_9[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 64, 64, 512)  0           conv2d_transpose[0][0]
#                                                                  conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 64, 64, 256)  1179904     concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 64, 64, 256)  590080      conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 128, 128, 128 131200      conv2d_11[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 128, 128, 256 0           conv2d_transpose_1[0][0]
#                                                                  conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 128, 128, 128 295040      concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 128, 128, 128 147584      conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 256, 256, 64) 32832       conv2d_13[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 256, 256, 128 0           conv2d_transpose_2[0][0]
#                                                                  conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 256, 256, 64) 73792       concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 256, 256, 64) 36928       conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 512, 512, 32) 8224        conv2d_15[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 512, 512, 64) 0           conv2d_transpose_3[0][0]
#                                                                  conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 512, 512, 32) 18464       concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 512, 512, 32) 9248        conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 512, 512, 1)  33          conv2d_17[0][0]
# ==================================================================================================
# Total params: 7,759,521
# Trainable params: 7,759,521
# Non-trainable params: 0
# __________________________________________________________________________________________________
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/optimizer_v2.py:356: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")

# %%
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, EarlyStopping, ReduceLROnPlateau
weight_path="{}_weights.best.hdf5".format('cxr_reg')

checkpoint = ModelCheckpoint(weight_path, monitor='val_loss', verbose=1, 
                             save_best_only=True, mode='min', save_weights_only = True)

reduceLROnPlat = ReduceLROnPlateau(monitor='val_loss', factor=0.5, 
                                   patience=3, 
                                   verbose=1, mode='min', epsilon=0.0001, cooldown=2, min_lr=1e-6)
early = EarlyStopping(monitor="val_loss", 
                      mode="min", 
                      patience=15) # probably needs to be more patient, but kaggle time is limited
callbacks_list = [checkpoint, early, reduceLROnPlat]
# Out:
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.

# %%
from IPython.display import clear_output
from tensorflow.keras.optimizers import Adam 
from sklearn.model_selection import train_test_split

model.compile(optimizer=Adam(lr=2e-4), 
              loss=[dice_coef_loss], 
           metrics = [dice_coef, 'binary_accuracy'])

train_vol, validation_vol, train_seg, validation_seg = train_test_split((images-127.0)/127.0, 
                                                            (mask>127).astype(np.float32), 
                                                            test_size = 0.1,random_state = 2018)

train_vol, test_vol, train_seg, test_seg = train_test_split(train_vol,train_seg, 
                                                            test_size = 0.1, 
                                                            random_state = 2018)

loss_history = model.fit(x = train_vol,
                       y = train_seg,
                         batch_size = 16,
                  epochs = 50,
                  validation_data =(test_vol,test_seg) ,
                  callbacks=callbacks_list)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/optimizer_v2.py:356: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")
# Epoch 1/50
# 18/18 [==============================] - 37s 876ms/step - loss: -0.3408 - dice_coef: 0.3459 - binary_accuracy: 0.5831 - val_loss: -0.3700 - val_dice_coef: 0.3700 - val_binary_accuracy: 0.5994
#
# Epoch 00001: val_loss improved from inf to -0.36999, saving model to cxr_reg_weights.best.hdf5
# Epoch 2/50
# 18/18 [==============================] - 6s 315ms/step - loss: -0.4386 - dice_coef: 0.4432 - binary_accuracy: 0.5693 - val_loss: -0.5001 - val_dice_coef: 0.5001 - val_binary_accuracy: 0.6166
#
# Epoch 00002: val_loss improved from -0.36999 to -0.50013, saving model to cxr_reg_weights.best.hdf5
# Epoch 3/50
# 18/18 [==============================] - 6s 312ms/step - loss: -0.5649 - dice_coef: 0.5681 - binary_accuracy: 0.6888 - val_loss: -0.2108 - val_dice_coef: 0.2108 - val_binary_accuracy: 0.7667
#
# Epoch 00003: val_loss did not improve from -0.50013
# Epoch 4/50
# 18/18 [==============================] - 6s 314ms/step - loss: -0.7187 - dice_coef: 0.7215 - binary_accuracy: 0.8612 - val_loss: -0.8057 - val_dice_coef: 0.8057 - val_binary_accuracy: 0.8833
#
# Epoch 00004: val_loss improved from -0.50013 to -0.80570, saving model to cxr_reg_weights.best.hdf5
# Epoch 5/50
# 18/18 [==============================] - 6s 314ms/step - loss: -0.8489 - dice_coef: 0.8500 - binary_accuracy: 0.9234 - val_loss: -0.8753 - val_dice_coef: 0.8753 - val_binary_accuracy: 0.9336
#
# Epoch 00005: val_loss improved from -0.80570 to -0.87530, saving model to cxr_reg_weights.best.hdf5
# Epoch 6/50
# 18/18 [==============================] - 6s 313ms/step - loss: -0.8767 - dice_coef: 0.8777 - binary_accuracy: 0.9374 - val_loss: -0.8877 - val_dice_coef: 0.8877 - val_binary_accuracy: 0.9420
#
# Epoch 00006: val_loss improved from -0.87530 to -0.88773, saving model to cxr_reg_weights.best.hdf5
# Epoch 7/50
# 18/18 [==============================] - 6s 314ms/step - loss: -0.8880 - dice_coef: 0.8891 - binary_accuracy: 0.9433 - val_loss: -0.8935 - val_dice_coef: 0.8935 - val_binary_accuracy: 0.9420
#
# Epoch 00007: val_loss improved from -0.88773 to -0.89351, saving model to cxr_reg_weights.best.hdf5
# Epoch 8/50
# 18/18 [==============================] - 6s 315ms/step - loss: -0.8993 - dice_coef: 0.9001 - binary_accuracy: 0.9497 - val_loss: -0.9063 - val_dice_coef: 0.9063 - val_binary_accuracy: 0.9495
#
# Epoch 00008: val_loss improved from -0.89351 to -0.90628, saving model to cxr_reg_weights.best.hdf5
# Epoch 9/50
# 18/18 [==============================] - 6s 310ms/step - loss: -0.9174 - dice_coef: 0.9174 - binary_accuracy: 0.9586 - val_loss: -0.9276 - val_dice_coef: 0.9276 - val_binary_accuracy: 0.9621
#
# Epoch 00009: val_loss improved from -0.90628 to -0.92762, saving model to cxr_reg_weights.best.hdf5
# Epoch 10/50
# 18/18 [==============================] - 6s 313ms/step - loss: -0.9291 - dice_coef: 0.9297 - binary_accuracy: 0.9648 - val_loss: -0.9337 - val_dice_coef: 0.9337 - val_binary_accuracy: 0.9664
#
# Epoch 00010: val_loss improved from -0.92762 to -0.93367, saving model to cxr_reg_weights.best.hdf5
# Epoch 11/50
# 18/18 [==============================] - 6s 310ms/step - loss: -0.9368 - dice_coef: 0.9373 - binary_accuracy: 0.9686 - val_loss: -0.9407 - val_dice_coef: 0.9407 - val_binary_accuracy: 0.9689
#
# Epoch 00011: val_loss improved from -0.93367 to -0.94073, saving model to cxr_reg_weights.best.hdf5
# Epoch 12/50
# 18/18 [==============================] - 6s 314ms/step - loss: -0.9388 - dice_coef: 0.9393 - binary_accuracy: 0.9696 - val_loss: -0.9449 - val_dice_coef: 0.9449 - val_binary_accuracy: 0.9711
#
# Epoch 00012: val_loss improved from -0.94073 to -0.94486, saving model to cxr_reg_weights.best.hdf5
# Epoch 13/50
# 18/18 [==============================] - 6s 312ms/step - loss: -0.9456 - dice_coef: 0.9461 - binary_accuracy: 0.9729 - val_loss: -0.9484 - val_dice_coef: 0.9484 - val_binary_accuracy: 0.9739
#
# Epoch 00013: val_loss improved from -0.94486 to -0.94840, saving model to cxr_reg_weights.best.hdf5
# Epoch 14/50
# 18/18 [==============================] - 6s 310ms/step - loss: -0.9469 - dice_coef: 0.9470 - binary_accuracy: 0.9737 - val_loss: -0.9399 - val_dice_coef: 0.9399 - val_binary_accuracy: 0.9679
#
# Epoch 00014: val_loss did not improve from -0.94840
# Epoch 15/50
# 18/18 [==============================] - 6s 312ms/step - loss: -0.9473 - dice_coef: 0.9475 - binary_accuracy: 0.9738 - val_loss: -0.9532 - val_dice_coef: 0.9532 - val_binary_accuracy: 0.9759
#
# Epoch 00015: val_loss improved from -0.94840 to -0.95318, saving model to cxr_reg_weights.best.hdf5
# Epoch 16/50
# 18/18 [==============================] - 6s 309ms/step - loss: -0.9475 - dice_coef: 0.9480 - binary_accuracy: 0.9738 - val_loss: -0.9300 - val_dice_coef: 0.9300 - val_binary_accuracy: 0.9622
#
# Epoch 00016: val_loss did not improve from -0.95318
# Epoch 17/50
# 18/18 [==============================] - 6s 332ms/step - loss: -0.9464 - dice_coef: 0.9469 - binary_accuracy: 0.9733 - val_loss: -0.9529 - val_dice_coef: 0.9529 - val_binary_accuracy: 0.9759
#
# Epoch 00017: val_loss did not improve from -0.95318
# Epoch 18/50
# 18/18 [==============================] - 6s 317ms/step - loss: -0.9523 - dice_coef: 0.9520 - binary_accuracy: 0.9763 - val_loss: -0.9544 - val_dice_coef: 0.9544 - val_binary_accuracy: 0.9763
#
# Epoch 00018: val_loss improved from -0.95318 to -0.95435, saving model to cxr_reg_weights.best.hdf5
# Epoch 19/50
# 18/18 [==============================] - 6s 318ms/step - loss: -0.9550 - dice_coef: 0.9554 - binary_accuracy: 0.9775 - val_loss: -0.9562 - val_dice_coef: 0.9562 - val_binary_accuracy: 0.9773
#
# Epoch 00019: val_loss improved from -0.95435 to -0.95617, saving model to cxr_reg_weights.best.hdf5
# Epoch 20/50
# 18/18 [==============================] - 6s 316ms/step - loss: -0.9562 - dice_coef: 0.9565 - binary_accuracy: 0.9782 - val_loss: -0.9576 - val_dice_coef: 0.9576 - val_binary_accuracy: 0.9783
#
# Epoch 00020: val_loss improved from -0.95617 to -0.95760, saving model to cxr_reg_weights.best.hdf5
# Epoch 21/50
# 18/18 [==============================] - 6s 319ms/step - loss: -0.9571 - dice_coef: 0.9575 - binary_accuracy: 0.9786 - val_loss: -0.9579 - val_dice_coef: 0.9579 - val_binary_accuracy: 0.9784
#
# Epoch 00021: val_loss improved from -0.95760 to -0.95788, saving model to cxr_reg_weights.best.hdf5
# Epoch 22/50
# 18/18 [==============================] - 6s 324ms/step - loss: -0.9543 - dice_coef: 0.9547 - binary_accuracy: 0.9774 - val_loss: -0.9539 - val_dice_coef: 0.9539 - val_binary_accuracy: 0.9760
#
# Epoch 00022: val_loss did not improve from -0.95788
# Epoch 23/50
# 18/18 [==============================] - 6s 340ms/step - loss: -0.9553 - dice_coef: 0.9557 - binary_accuracy: 0.9777 - val_loss: -0.9570 - val_dice_coef: 0.9570 - val_binary_accuracy: 0.9780
#
# Epoch 00023: val_loss did not improve from -0.95788
# Epoch 24/50
# 18/18 [==============================] - 6s 332ms/step - loss: -0.9572 - dice_coef: 0.9576 - binary_accuracy: 0.9787 - val_loss: -0.9596 - val_dice_coef: 0.9596 - val_binary_accuracy: 0.9793
#
# Epoch 00024: val_loss improved from -0.95788 to -0.95962, saving model to cxr_reg_weights.best.hdf5
# Epoch 25/50
# 18/18 [==============================] - 6s 320ms/step - loss: -0.9593 - dice_coef: 0.9596 - binary_accuracy: 0.9797 - val_loss: -0.9593 - val_dice_coef: 0.9593 - val_binary_accuracy: 0.9792
#
# Epoch 00025: val_loss did not improve from -0.95962
# Epoch 26/50
# 18/18 [==============================] - 6s 319ms/step - loss: -0.9595 - dice_coef: 0.9600 - binary_accuracy: 0.9799 - val_loss: -0.9603 - val_dice_coef: 0.9603 - val_binary_accuracy: 0.9796
#
# Epoch 00026: val_loss improved from -0.95962 to -0.96031, saving model to cxr_reg_weights.best.hdf5
# Epoch 27/50
# 18/18 [==============================] - 6s 324ms/step - loss: -0.9601 - dice_coef: 0.9604 - binary_accuracy: 0.9799 - val_loss: -0.9600 - val_dice_coef: 0.9600 - val_binary_accuracy: 0.9793
#
# Epoch 00027: val_loss did not improve from -0.96031
# Epoch 28/50
# 18/18 [==============================] - 6s 322ms/step - loss: -0.9604 - dice_coef: 0.9607 - binary_accuracy: 0.9803 - val_loss: -0.9599 - val_dice_coef: 0.9599 - val_binary_accuracy: 0.9795
#
# Epoch 00028: val_loss did not improve from -0.96031
# Epoch 29/50
# 18/18 [==============================] - 6s 320ms/step - loss: -0.9609 - dice_coef: 0.9613 - binary_accuracy: 0.9804 - val_loss: -0.9606 - val_dice_coef: 0.9606 - val_binary_accuracy: 0.9798
#
# Epoch 00029: val_loss improved from -0.96031 to -0.96061, saving model to cxr_reg_weights.best.hdf5
# Epoch 30/50
# 18/18 [==============================] - 6s 318ms/step - loss: -0.9611 - dice_coef: 0.9614 - binary_accuracy: 0.9806 - val_loss: -0.9610 - val_dice_coef: 0.9610 - val_binary_accuracy: 0.9799
#
# Epoch 00030: val_loss improved from -0.96061 to -0.96098, saving model to cxr_reg_weights.best.hdf5
# Epoch 31/50
# 18/18 [==============================] - 6s 318ms/step - loss: -0.9618 - dice_coef: 0.9621 - binary_accuracy: 0.9808 - val_loss: -0.9611 - val_dice_coef: 0.9611 - val_binary_accuracy: 0.9801
#
# Epoch 00031: val_loss improved from -0.96098 to -0.96111, saving model to cxr_reg_weights.best.hdf5
# Epoch 32/50
# 18/18 [==============================] - 6s 317ms/step - loss: -0.9609 - dice_coef: 0.9610 - binary_accuracy: 0.9805 - val_loss: -0.9601 - val_dice_coef: 0.9601 - val_binary_accuracy: 0.9794
#
# Epoch 00032: val_loss did not improve from -0.96111
# Epoch 33/50
# 18/18 [==============================] - 6s 318ms/step - loss: -0.8480 - dice_coef: 0.8485 - binary_accuracy: 0.9210 - val_loss: -0.8665 - val_dice_coef: 0.8665 - val_binary_accuracy: 0.9345
#
# Epoch 00033: val_loss did not improve from -0.96111
# Epoch 34/50
# 18/18 [==============================] - 6s 318ms/step - loss: -0.9008 - dice_coef: 0.9017 - binary_accuracy: 0.9503 - val_loss: -0.9240 - val_dice_coef: 0.9240 - val_binary_accuracy: 0.9603
#
# Epoch 00034: val_loss did not improve from -0.96111
#
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-05.
# Epoch 35/50
# 18/18 [==============================] - 6s 318ms/step - loss: -0.9363 - dice_coef: 0.9368 - binary_accuracy: 0.9683 - val_loss: -0.9446 - val_dice_coef: 0.9446 - val_binary_accuracy: 0.9714
#
# Epoch 00035: val_loss did not improve from -0.96111
# Epoch 36/50
# 18/18 [==============================] - 6s 314ms/step - loss: -0.9457 - dice_coef: 0.9462 - binary_accuracy: 0.9729 - val_loss: -0.9511 - val_dice_coef: 0.9511 - val_binary_accuracy: 0.9748
#
# Epoch 00036: val_loss did not improve from -0.96111
# Epoch 37/50
# 18/18 [==============================] - 6s 319ms/step - loss: -0.9509 - dice_coef: 0.9512 - binary_accuracy: 0.9757 - val_loss: -0.9542 - val_dice_coef: 0.9542 - val_binary_accuracy: 0.9765
#
# Epoch 00037: val_loss did not improve from -0.96111
# Epoch 38/50
# 18/18 [==============================] - 6s 318ms/step - loss: -0.9539 - dice_coef: 0.9542 - binary_accuracy: 0.9770 - val_loss: -0.9566 - val_dice_coef: 0.9566 - val_binary_accuracy: 0.9776
#
# Epoch 00038: val_loss did not improve from -0.96111
#
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# Epoch 39/50
# 18/18 [==============================] - 6s 324ms/step - loss: -0.9551 - dice_coef: 0.9554 - binary_accuracy: 0.9777 - val_loss: -0.9565 - val_dice_coef: 0.9565 - val_binary_accuracy: 0.9777
#
# Epoch 00039: val_loss did not improve from -0.96111
# Epoch 40/50
# 18/18 [==============================] - 6s 316ms/step - loss: -0.9564 - dice_coef: 0.9565 - binary_accuracy: 0.9782 - val_loss: -0.9578 - val_dice_coef: 0.9578 - val_binary_accuracy: 0.9783
#
# Epoch 00040: val_loss did not improve from -0.96111
# Epoch 41/50
# 18/18 [==============================] - 6s 316ms/step - loss: -0.9569 - dice_coef: 0.9573 - binary_accuracy: 0.9786 - val_loss: -0.9582 - val_dice_coef: 0.9582 - val_binary_accuracy: 0.9786
#
# Epoch 00041: val_loss did not improve from -0.96111
# Epoch 42/50
# 18/18 [==============================] - 6s 315ms/step - loss: -0.9575 - dice_coef: 0.9578 - binary_accuracy: 0.9788 - val_loss: -0.9584 - val_dice_coef: 0.9584 - val_binary_accuracy: 0.9785
#
# Epoch 00042: val_loss did not improve from -0.96111
#
# Epoch 00042: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# Epoch 43/50
# 18/18 [==============================] - 6s 317ms/step - loss: -0.9582 - dice_coef: 0.9586 - binary_accuracy: 0.9791 - val_loss: -0.9589 - val_dice_coef: 0.9589 - val_binary_accuracy: 0.9789
#
# Epoch 00043: val_loss did not improve from -0.96111
# Epoch 44/50
# 18/18 [==============================] - 6s 314ms/step - loss: -0.9583 - dice_coef: 0.9586 - binary_accuracy: 0.9792 - val_loss: -0.9592 - val_dice_coef: 0.9592 - val_binary_accuracy: 0.9790
#
# Epoch 00044: val_loss did not improve from -0.96111
# Epoch 45/50
# 18/18 [==============================] - 6s 360ms/step - loss: -0.9587 - dice_coef: 0.9590 - binary_accuracy: 0.9794 - val_loss: -0.9593 - val_dice_coef: 0.9593 - val_binary_accuracy: 0.9792
#
# Epoch 00045: val_loss did not improve from -0.96111
# Epoch 46/50
# 18/18 [==============================] - 6s 312ms/step - loss: -0.9591 - dice_coef: 0.9592 - binary_accuracy: 0.9795 - val_loss: -0.9593 - val_dice_coef: 0.9593 - val_binary_accuracy: 0.9791
#
# Epoch 00046: val_loss did not improve from -0.96111
#
# Epoch 00046: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize = (10, 5))
ax1.plot(loss_history.history['loss'], '-', label = 'Loss')
ax1.plot(loss_history.history['val_loss'], '-', label = 'Validation Loss')
ax1.legend()

ax2.plot(100*np.array(loss_history.history['binary_accuracy']), '-', 
         label = 'Accuracy')
ax2.plot(100*np.array(loss_history.history['val_binary_accuracy']), '-',
         label = 'Validation Accuracy')
ax2.legend()

# %%
pred_candidates = np.random.randint(1,validation_vol.shape[0],10)
preds = model.predict(validation_vol)

plt.figure(figsize=(20,10))

for i in range(0,9,3):
    plt.subplot(3,3,i+1)
    
    plt.imshow(np.squeeze(validation_vol[pred_candidates[i]]))
    plt.xlabel("Base Image")
    
    
    plt.subplot(3,3,i+2)
    plt.imshow(np.squeeze(validation_seg[pred_candidates[i]]))
    plt.xlabel("Mask")
    
    plt.subplot(3,3,i+3)
    plt.imshow(np.squeeze(preds[pred_candidates[i]]))
    plt.xlabel("Pridiction")

# %%
model.save("model.h5")

# %%
import tensorflow
mm = tensorflow.keras.models.load_model("model.h5", custom_objects={'dice_coef':dice_coef, 'dice_coef_loss':dice_coef_loss})

# %%
def test_predict(image, model):
  image = cv2.cvtColor(cv2.imread("xray1.jpg"), cv2.COLOR_BGR2GRAY)
  img = (image-127.)/127.
  img = cv2.resize(img, (512,512))
  img = np.expand_dims(img, axis=0)
  pred = model.predict(img)

  plt.figure(figsize=(10,10))
  plt.subplot(1,2,1)
  plt.imshow(image, cmap="gray")
  plt.subplot(1,2,2)
  plt.imshow(np.squeeze(pred[0]), cmap="gray")

# %%
test_predict("xray1.jpg", model)

# %%
test_predict("xray2.jpg", mm)

# %%
m_test = unet(input_size=(512,512,1))
m_test.compile(optimizer=tf.keras.optimizers.Adam(lr=1e-5), loss=dice_coef_loss,
                    metrics=[dice_coef, 'binary_accuracy'])
m_test.load_weights('cxr_reg_weights.best.hdf5')
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/optimizer_v2.py:356: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")

# %%
test_predict("xray1.jpg", m_test)

# %%
m_test.save("best_model_lungs_segmentation.h5")

# %%
# !cp best_model_lungs_segmentation.h5 "gdrive/MyDrive/Lung_Segmentation_Weights/best_model_lungs_segmentation.h5"
